# %% [markdown]
# https://data.sfgov.org/Public-Safety/Fire-Department-Calls-for-Service/nuek-vuh3

# %% [markdown]
# #### Import Packages

# %%
import pyspark.sql.functions as F
from pyspark.sql import Window

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('max_columns',100)

# %% [markdown]
# #### Load Data Into Spark

# %%
df = spark\
    .read\
    .option("header",True)\
    .option("inferSchema",True)\
    .csv('RAWDATA/Fire_Department_Calls_for_Service.csv')

# %% [markdown]
# #### Properly Format Columns

# %%
# Format Dates
for dt_col in ['Call Date','Watch Date']:
    df = df.withColumn(dt_col, F.to_date(F.col(dt_col),format='mm/dd/yyyy'))

# %%
# Format Timestamps
for ts_col in ['Received DtTm','Entry DtTm','Dispatch DtTm','Response DtTm','On Scene DtTm','Transport DtTm',
              'Hospital DtTm','Available DtTm']:
    df = df.withColumn(ts_col, F.to_timestamp(ts_col, format='mm/dd/yyyy hh:mm:ss a'))

# %% [markdown]
# #### Preview Data

# %%
df_preview = df.limit(100).toPandas()

# %%
df_preview.head()
# Out:
#    Call Number Unit ID  Incident Number         Call Type   Call Date  \
# 0     60640268     E17          6018058            Alarms  2006-01-05
# 1     60560284     T15          6015653    Structure Fire  2006-01-25
# 2     61480176     T05          6041096            Alarms  2006-01-28
# 3     61180215     M36          6032760  Medical Incident  2006-01-28
# 4     61030317     RC2          6028690  Medical Incident  2006-01-13
#
#    Watch Date       Received DtTm          Entry DtTm       Dispatch DtTm  \
# 0  2006-01-05 2006-01-05 18:37:01 2006-01-05 18:45:24 2006-01-05 18:45:39
# 1  2006-01-25 2006-01-25 18:17:35 2006-01-25 18:17:35 2006-01-25 18:17:49
# 2  2006-01-28 2006-01-28 12:39:31 2006-01-28 12:41:04 2006-01-28 12:41:11
# 3  2006-01-28 2006-01-28 12:59:36 2006-01-28 13:02:52 2006-01-28 13:03:46
# 4  2006-01-13 2006-01-13 16:24:38 2006-01-13 16:25:50 2006-01-13 16:27:01
#
#         Response DtTm       On Scene DtTm Transport DtTm Hospital DtTm  \
# 0                 NaT 2006-01-05 18:50:08            NaT           NaT
# 1 2006-01-25 18:18:41 2006-01-25 18:20:05            NaT           NaT
# 2 2006-01-28 12:42:01 2006-01-28 12:43:29            NaT           NaT
# 3 2006-01-28 13:05:24 2006-01-28 13:06:02            NaT           NaT
# 4 2006-01-13 16:28:01 2006-01-13 16:32:03            NaT           NaT
#
#        Call Final Disposition      Available DtTm                    Address  \
# 0                       Other 2006-01-05 19:07:05  1300 Block of OAKDALE AVE
# 1                        Fire 2006-01-25 18:21:16          GENEVA AV/TARA ST
# 2                       Other                 NaT      1500 Block of EDDY ST
# 3  Patient Declined Transport 2006-01-28 13:10:33  600 Block of STEVENSON ST
# 4                       Other 2006-01-13 16:47:15      700 Block of 35TH AVE
#
#   City  Zipcode of Incident Battalion Station Area   Box Original Priority  \
# 0   SF              94124.0       B10           17  0653                 3
# 1   SF              94112.0       B09           15  8313                 3
# 2   SF              94115.0       B05           05  3624                 3
# 3   SF              94103.0       B02           01  2316                 3
# 4   SF              94121.0       B07           34  7252                 3
#
#   Priority  Final Priority  ALS Unit Call Type Group  Number of Alarms  \
# 0        3               3      True            None                 1
# 1        3               3     False            None                 1
# 2        3               3     False            None                 1
# 3        3               3      True            None                 1
# 4        3               3      True            None                 1
#
#         Unit Type  Unit sequence in call dispatch Fire Prevention District  \
# 0          ENGINE                               1                       10
# 1           TRUCK                               1                        9
# 2           TRUCK                               1                        5
# 3           MEDIC                               1                        2
# 4  RESCUE CAPTAIN                               2                        7
#
#   Supervisor District Neighborhooods - Analysis Boundaries  \
# 0                  10                Bayview Hunters Point
# 1                  11           Oceanview/Merced/Ingleside
# 2                   5                     Western Addition
# 3                   6                      South of Market
# 4                   1                       Outer Richmond
#
#                                Location          RowID  \
# 0  (37.732342352455, -122.386280381355)  060640268-E17
# 1  (37.721396869221, -122.448410646975)  060560284-T15
# 2  (37.781269356473, -122.433140098256)  061480176-T05
# 3  (37.779523171162, -122.412639291793)  061180215-M36
# 4  (37.774876893512, -122.495176037656)  061030317-RC2
#
#                                        shape  Supervisor Districts  \
# 0  POINT (-122.386280381355 37.732342352455)                   8.0
# 1  POINT (-122.448410646975 37.721396869221)                   6.0
# 2  POINT (-122.433140098256 37.781269356473)                  11.0
# 3  POINT (-122.412639291793 37.779523171162)                   9.0
# 4  POINT (-122.495176037656 37.774876893512)                   2.0
#
#    Fire Prevention Districts  Current Police Districts  \
# 0                       10.0                       3.0
# 1                        9.0                       5.0
# 2                       15.0                       6.0
# 3                        8.0                       2.0
# 4                       11.0                       9.0
#
#    Neighborhoods - Analysis Boundaries  Zip Codes  Neighborhoods (old)  \
# 0                                  1.0         58                  1.0
# 1                                 24.0      28861                 24.0
# 2                                 39.0      29490                 41.0
# 3                                 34.0      28853                 34.0
# 4                                 29.0         55                 26.0
#
#    Police Districts  Civic Center Harm Reduction Project Boundary  HSOC Zones  \
# 0               3.0                                           NaN         NaN
# 1               8.0                                           NaN         NaN
# 2               9.0                                           NaN         NaN
# 3               2.0                                           1.0         1.0
# 4               6.0                                           NaN         NaN
#
#    Central Market/Tenderloin Boundary Polygon - Updated  Neighborhoods  \
# 0                                                NaN              86.0
# 1                                                NaN              81.0
# 2                                                NaN              97.0
# 3                                                1.0              32.0
# 4                                                NaN               8.0
#
#    SF Find Neighborhoods  Current Police Districts 2  \
# 0                   86.0                         2.0
# 1                   81.0                        10.0
# 2                   97.0                         4.0
# 3                   32.0                         5.0
# 4                    8.0                         8.0
#
#    Current Supervisor Districts
# 0                           9.0
# 1                           1.0
# 2                          11.0
# 3                          10.0
# 4                           4.0

# %% [markdown]
# #### Quick EDA to Understand Data Characteristics

# %%
df_counts_call_date = df\
    .groupBy('Call Date')\
    .agg(F.countDistinct('Incident Number').alias('Unique Incidents'),
         F.count('Call Date').alias('Total Calls'))\
    .toPandas()

# %%
df_counts_call_date['Call Date'] = pd.to_datetime(df_counts_call_date['Call Date'])

# %%
df_counts_call_date.set_index('Call Date').sort_index().plot(figsize=[15,5]);

# %%
df_counts_call_date['CallYear'] = df_counts_call_date['Call Date'].dt.year.astype(str)
df_counts_call_date['CallMonth'] = df_counts_call_date['Call Date'].dt.month

# %%
df_counts_call_date.groupby('CallYear')[['Unique Incidents','Total Calls']].sum().plot(figsize=[15,5])

# %%
df_counts_call_date.groupby(['CallYear','CallMonth'])[['Unique Incidents','Total Calls']].sum()
# Out:
#                     Unique Incidents  Total Calls
# CallYear CallMonth
# 2000     1                     76660       158154
# 2001     1                    108856       220328
# 2002     1                    106285       225951
# 2003     1                    102565       240457
# 2004     1                     99447       235353
# 2005     1                     98080       232919
# 2006     1                    101630       235440
# 2007     1                    103238       235856
# 2008     1                    109491       249690
# 2009     1                    108105       244633
# 2010     1                    115265       256174
# 2011     1                    118966       268689
# 2012     1                    120648       265596
# 2013     1                    121761       273097
# 2014     1                    124698       280905
# 2015     1                    135402       296244
# 2016     1                    141978       303967
# 2017     1                    148373       312471
# 2018     1                    149142       310700
# 2019     1                    153194       319855
# 2020     1                    104064       213335

# %%
df_counts_call_type = df\
    .groupBy('Call Date','Call Type')\
    .agg(F.countDistinct('Incident Number').alias('Unique Incidents'),
         F.count('Call Date').alias('Total Calls'))\
    .toPandas()

# %%
df_counts_call_type['Call Date'] = pd.to_datetime(df_counts_call_type['Call Date'])

# %%
df_counts_call_type.groupby('Call Type').sum().sort_values('Unique Incidents', ascending=False).head(10)
# Out:
#                                Unique Incidents  Total Calls
# Call Type
# Medical Incident                        1772267      3515505
# Alarms                                   196231       584187
# Structure Fire                           156893       672264
# Traffic Collision                         78585       220132
# Citizen Assist / Service Call             64116        80370
# Other                                     61605        85131
# Outside Fire                              44263        66021
# Electrical Hazard                         14138        16217
# Elevator / Escalator Rescue               12873        14540
# Vehicle Fire                              11449        25006

# %% [markdown]
# #### Define "turnout times"

# %%
df = df\
    .withColumn('TurnoutTime_sec', F.col('On Scene DtTm').cast('long') - F.col('Response DtTm').cast('long'))\
    .withColumn('TurnoutTime_min', F.col('TurnoutTime_sec')/60)

# %% [markdown]
# #### Create Features to Identify "Evening incidents"

# %%
df = df\
    .withColumn('Evening Incident', F.when((F.hour('Dispatch DtTm')>= 18)&(F.hour('Dispatch DtTm')< 23),"YES").otherwise("NO"))

# %%
df_incident_types = df.groupby('Evening Incident')\
    .agg(F.countDistinct('Incident Number').alias('Unique Incidents'),
         F.mean('TurnoutTime_min').alias('Average Turnout Time (min)'))\
    .toPandas()

# %%
df_incident_types
# Out:
#   Evening Incident  Unique Incidents  Average Turnout Time (min)
# 0              YES            584652                    4.405017
# 1               NO           1865403                    9.579772

# %% [markdown]
# #### Create Features to Identify "back to back responses"
# - Create a feature that increments by 1 for each call
# - Join on that count - 1 to get the last incident time for each unit
# - Flag units that have become available less than 10 minutes ago

# %%
# Create Column with Row Number by Call Date and Unit ID
w = Window.partitionBy(df['Call Date'],df['Unit ID']).orderBy(df['Available DtTm'])
df = df.withColumn('rnum',F.row_number().over(w))

# Create dataframe with prior call's available time
df_shift = df.select('Call Date','Unit ID','Available DtTm','rnum')
# Add 1 to row number to join to master dataframe
df_shift = df_shift.withColumn('rnum', F.col('rnum')+1)
# Rename Column
df_shift = df_shift.withColumnRenamed('Available DtTm','Prior Available DtTm')

# Join on Prior Call's Available Time
df = df.join(df_shift, on=['Call Date','Unit ID','rnum'], how='left')

# Calculate Time since Previous Incident
df = df.withColumn('TimeSinceLastAvailable_sec', F.col('Dispatch DtTm').cast('long') - F.col('Prior Available DtTm').cast('long'))\
    .withColumn('TimeSinceLastAvailable_min', F.col('TimeSinceLastAvailable_sec')/60)

# %% [markdown]
# # Task 1a: Evening incidents have slower turnout times
# Evening incidents are incidents that are created between the hours of 10:00 PM and 6:00 AM.

# %% [markdown]
# #### Prepare Pandas Data Frame for Analysis

# %%
df_incident_time = df\
    .select('Call Date','Evening Incident','Call Type','TurnoutTime_min')\
    .toPandas()

# %% [markdown]
# ## Quick Visualizations (Identify if Data Quality Issues Exist)

# %% [markdown]
# # Task 1b: Units with back to back responses have slower turnout times
# A back to back response is defined by a unit being dispatched within 10 minutes of becoming available since the previous incident.

# %% [markdown]
# #### Prepare Pandas Data Frame for Analysis

# %% [markdown]
# ## Quick Visualizations (Identify if Data Quality Issues Exist)

# %% [markdown]
# # Task 2: Additional trends
#
# Ideas:
# - Location Based Trends
# - Trends over Time
#     - Growth by Incident Type
#     - Response Time
# - Number of Unique Units per Incident (Labor)
