# %% [markdown]
# # Fire Department Incident Analysis

# %% [markdown]
# https://data.sfgov.org/Public-Safety/Fire-Department-Calls-for-Service/nuek-vuh3

# %% [markdown]
# #### Import Packages

# %%
import pyspark.sql.functions as F
from pyspark.sql import Window

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('max_columns',100)

# %% [markdown]
# #### Load Data Into Spark

# %%
df = spark\
    .read\
    .option("header",True)\
    .option("inferSchema",True)\
    .csv('RAWDATA/Fire_Department_Calls_for_Service.csv')

# %% [markdown]
# #### Properly Format Columns

# %%
# Format Dates
for dt_col in ['Call Date','Watch Date']:
    df = df.withColumn(dt_col, F.to_date(F.col(dt_col),format='mm/dd/yyyy'))

# %%
# Format Timestamps
for ts_col in ['Received DtTm','Entry DtTm','Dispatch DtTm','Response DtTm','On Scene DtTm','Transport DtTm',
              'Hospital DtTm','Available DtTm']:
    df = df.withColumn(ts_col, F.to_timestamp(ts_col, format='mm/dd/yyyy hh:mm:ss a'))

# %%
df = df.filter(F.year('Call Date')==2019)

# %% [markdown]
# #### Preview Data

# %%
df_preview = df.limit(100).toPandas()

# %%
df_preview.head()
# Out:
#    Call Number Unit ID  Incident Number     Call Type   Call Date  Watch Date  \
# 0    192642361      D2         19113136  Water Rescue  2019-01-21  2019-01-21
# 1    193400777     E36         19146741         Other  2019-01-06  2019-01-05
# 2    190033206     B01         19001249        Alarms  2019-01-03  2019-01-03
# 3    190040628     B01         19001418        Alarms  2019-01-04  2019-01-03
# 4    190044011      AP         19001768         Other  2019-01-04  2019-01-04
#
#         Received DtTm          Entry DtTm       Dispatch DtTm  \
# 0 2019-01-21 14:24:22 2019-01-21 14:27:18 2019-01-21 14:47:46
# 1 2019-01-06 07:51:32 2019-01-06 07:55:55 2019-01-06 07:56:29
# 2 2019-01-03 19:07:41 2019-01-03 19:10:16 2019-01-03 19:10:21
# 3 2019-01-04 07:57:15 2019-01-04 07:58:51 2019-01-04 07:59:05
# 4 2019-01-04 23:53:48 2019-01-04 23:53:48 2019-01-04 23:53:48
#
#         Response DtTm       On Scene DtTm Transport DtTm Hospital DtTm  \
# 0 2019-01-21 14:47:46                 NaT           None          None
# 1 2019-01-06 07:56:29                 NaT           None          None
# 2 2019-01-03 19:10:29 2019-01-03 19:17:28           None          None
# 3 2019-01-04 08:01:24                 NaT           None          None
# 4 2019-01-04 23:53:48 2019-01-04 23:53:48           None          None
#
#   Call Final Disposition      Available DtTm  \
# 0                   Fire 2019-01-21 14:50:19
# 1                   Fire 2019-01-06 09:57:47
# 2                   Fire 2019-01-03 19:29:36
# 3                   Fire 2019-01-04 08:06:13
# 4                   Fire 2019-01-04 23:53:48
#
#                               Address           City  Zipcode of Incident  \
# 0           400 Block of SEACLIFF AVE  San Francisco              94121.0
# 1  CALL BOX: SF INTERNATIONAL AIRPORT           None                  NaN
# 2                     2336-A JONES ST  San Francisco              94133.0
# 3              500 Block of SUTTER ST  San Francisco              94108.0
# 4  CALL BOX: SF INTERNATIONAL AIRPORT           None                  NaN
#
#   Battalion Station Area   Box Original Priority Priority  Final Priority  \
# 0       B07           14  7232                 3        3               3
# 1       B09           44  6913                 3        3               3
# 2       B01           28  1515                 3        3               3
# 3       B01           41  1412                 3        3               3
# 4       B09           44  6913                 3        3               3
#
#    ALS Unit Call Type Group  Number of Alarms Unit Type  \
# 0     False            Fire                 1     CHIEF
# 1      True           Alarm                 1    ENGINE
# 2     False           Alarm                 1     CHIEF
# 3     False           Alarm                 1     CHIEF
# 4     False           Alarm                 1   AIRPORT
#
#    Unit sequence in call dispatch Fire Prevention District  \
# 0                              19                        7
# 1                               1                     None
# 2                               3                        1
# 3                               3                        1
# 4                               1                     None
#
#   Supervisor District Neighborhooods - Analysis Boundaries  \
# 0                   2                             Seacliff
# 1                None                                 None
# 2                   3                         Russian Hill
# 3                   3                             Nob Hill
# 4                None                                 None
#
#                                    Location          RowID  \
# 0  (37.78754542686373, -122.49020028408141)   192642361-D2
# 1   (37.61688232392507, -122.3840942380982)  193400777-E36
# 2      (37.802896951185, -122.416350973227)  190033206-B01
# 3       (37.78917521379, -122.409429683066)  190040628-B01
# 4      (37.616882323925, -122.384094238098)   190044011-AP
#
#                                            shape  Supervisor Districts  \
# 0  POINT (-122.49020028408141 37.78754542686373)                   1.0
# 1   POINT (-122.3840942380982 37.61688232392507)                   NaN
# 2      POINT (-122.416350973227 37.802896951185)                  10.0
# 3       POINT (-122.409429683066 37.78917521379)                  10.0
# 4      POINT (-122.384094238098 37.616882323925)                   NaN
#
#    Fire Prevention Districts  Current Police Districts  \
# 0                       11.0                       9.0
# 1                        NaN                       NaN
# 2                        5.0                       1.0
# 3                        5.0                       1.0
# 4                        NaN                       NaN
#
#    Neighborhoods - Analysis Boundaries  Zip Codes  Neighborhoods (old)  \
# 0                                 33.0         55                 33.0
# 1                                  NaN         60                  NaN
# 2                                 32.0        308                 32.0
# 3                                 21.0      28857                 21.0
# 4                                  NaN         60                  NaN
#
#    Police Districts  Civic Center Harm Reduction Project Boundary  HSOC Zones  \
# 0               6.0                                           NaN         NaN
# 1               NaN                                           NaN         NaN
# 2               1.0                                           NaN         NaN
# 3               1.0                                           NaN         NaN
# 4               NaN                                           NaN         NaN
#
#    Central Market/Tenderloin Boundary Polygon - Updated  Neighborhoods  \
# 0                                                NaN               1.0
# 1                                                NaN               NaN
# 2                                                NaN             107.0
# 3                                                NaN              19.0
# 4                                                NaN               NaN
#
#    SF Find Neighborhoods  Current Police Districts 2  \
# 0                    1.0                         8.0
# 1                    NaN                         NaN
# 2                  107.0                         6.0
# 3                   19.0                         6.0
# 4                    NaN                         NaN
#
#    Current Supervisor Districts
# 0                           6.0
# 1                           NaN
# 2                           3.0
# 3                           3.0
# 4                           NaN

# %% [markdown]
# #### Quick EDA to Understand Data Characteristics

# %%
df_counts_call_date = df\
    .groupBy('Call Date')\
    .agg(F.countDistinct('Incident Number').alias('Unique Incidents'),
         F.count('Call Date').alias('Total Calls'))\
    .toPandas()

# %%
df_counts_call_date['Call Date'] = pd.to_datetime(df_counts_call_date['Call Date'])

# %%
df_counts_call_date.set_index('Call Date').sort_index().plot(figsize=[15,5]);

# %%
df_counts_call_date['CallYear'] = df_counts_call_date['Call Date'].dt.year.astype(str)
df_counts_call_date['CallMonth'] = df_counts_call_date['Call Date'].dt.month

# %%
df_counts_call_date.groupby('CallYear')[['Unique Incidents','Total Calls']].sum().plot(figsize=[15,5])

# %%
df_counts_call_date.groupby(['CallYear','CallMonth'])[['Unique Incidents','Total Calls']].sum()
# Out:
#                     Unique Incidents  Total Calls
# CallYear CallMonth
# 2019     1                    153194       319855

# %%
df_counts_call_type = df\
    .groupBy('Call Date','Call Type')\
    .agg(F.countDistinct('Incident Number').alias('Unique Incidents'),
         F.count('Call Date').alias('Total Calls'))\
    .toPandas()

# %%
df_counts_call_type['Call Date'] = pd.to_datetime(df_counts_call_type['Call Date'])

# %%
df_counts_call_type.groupby('Call Type').sum().sort_values('Unique Incidents', ascending=False).head(10)
# Out:
#                                  Unique Incidents  Total Calls
# Call Type
# Medical Incident                           116975       219470
# Alarms                                      12474        38377
# Traffic Collision                            4849        13671
# Structure Fire                               4745        25291
# Citizen Assist / Service Call                3441         4406
# Outside Fire                                 2829         4294
# Other                                        2781         4335
# Electrical Hazard                            1508         1623
# Elevator / Escalator Rescue                  1042         1147
# Gas Leak (Natural and LP Gases)               868         1995

# %% [markdown]
# #### Define "turnout times"

# %%
df = df\
    .withColumn('TurnoutTime_sec', F.col('Response DtTm').cast('long') - F.col('Dispatch DtTm').cast('long'))\
    .withColumn('TurnoutTime_min', F.col('TurnoutTime_sec')/60)

# %% [markdown]
# #### Create Features to Identify "Evening incidents"

# %%
df = df\
    .withColumn('Evening Incident', F.when((F.hour('Dispatch DtTm')>= 18)&(F.hour('Dispatch DtTm')< 23),"YES").otherwise("NO"))

# %%
df_incident_types = df.groupby('Evening Incident')\
    .agg(F.countDistinct('Incident Number').alias('Unique Incidents'),
         F.mean('TurnoutTime_min').alias('Average Turnout Time (min)'))\
    .toPandas()

# %%
df_incident_types
# Out:
#   Evening Incident  Unique Incidents  Average Turnout Time (min)
# 0              YES             36270                    0.878116
# 1               NO            117165                    0.777117

# %% [markdown]
# #### Create Features to Identify "back to back responses"
# - Create a feature that increments by 1 for each call
# - Join on that count - 1 to get the last incident time for each unit
# - Flag units that have become available less than 10 minutes ago

# %%
# Create Column with Row Number by Call Date and Unit ID
w = Window.partitionBy(df['Call Date'],df['Unit ID']).orderBy(df['Available DtTm'])
df = df.withColumn('rnum',F.row_number().over(w))

# Create dataframe with prior call's available time
df_shift = df.select('Call Date','Unit ID','Available DtTm','rnum')
# Add 1 to row number to join to master dataframe
df_shift = df_shift.withColumn('rnum', F.col('rnum')+1)
# Rename Column
df_shift = df_shift.withColumnRenamed('Available DtTm','Prior Available DtTm')

# Join on Prior Call's Available Time
df = df.join(df_shift, on=['Call Date','Unit ID','rnum'], how='left')

# Calculate Time since Previous Incident
df = df.withColumn('TimeSinceLastAvailable_sec', F.col('Dispatch DtTm').cast('long') - F.col('Prior Available DtTm').cast('long'))\
    .withColumn('TimeSinceLastAvailable_min', F.col('TimeSinceLastAvailable_sec')/60)

# %%
df_pandas = df.filter(F.col('Call Date')=='2019-01-31').toPandas()

df_pandas.TimeSinceLastAvailable_min.describe()
# Out:
# count     5999.000000
# mean       686.086962
# std       5439.536201
# min       -155.150000
# 25%        -25.758333
# 50%         -0.483333
# 75%         16.800000
# max      44635.516667
# Name: TimeSinceLastAvailable_min, dtype: float64

# %%
df_pandas[df_pandas['Unit ID']=='E06'].sort_values('Available DtTm').head(10)
# Out:
#        Call Date Unit ID  rnum  Call Number  Incident Number  \
# 4217  2019-01-31     E06     1    192430047         19103367
# 542   2019-01-31     E06     2    190900126         19038220
# 4664  2019-01-31     E06     3    192120094         19089937
# 6065  2019-01-31     E06     4    191510117         19063719
# 2257  2019-01-31     E06     5    190900172         19038227
# 4547  2019-01-31     E06     6    192120170         19089948
# 1356  2019-01-31     E06     7    193650218         19157799
# 4179  2019-01-31     E06     8    192430303         19103402
# 1999  2019-01-31     E06     9    192430361         19103410
# 817   2019-01-31     E06    10    193040249         19131280
#
#               Call Type  Watch Date       Received DtTm          Entry DtTm  \
# 4217  Traffic Collision  2019-01-30 2019-01-31 00:18:59 2019-01-31 00:21:26
# 542    Medical Incident  2019-01-30 2019-01-31 00:42:33 2019-01-31 00:45:38
# 4664   Medical Incident  2019-01-30 2019-01-31 00:51:44 2019-01-31 00:56:10
# 6065   Medical Incident  2019-01-30 2019-01-31 01:20:55 2019-01-31 01:20:55
# 2257   Medical Incident  2019-01-30 2019-01-31 01:04:16 2019-01-31 01:08:10
# 4547   Medical Incident  2019-01-30 2019-01-31 02:00:11 2019-01-31 02:00:49
# 1356   Medical Incident  2019-01-30 2019-01-31 02:16:00 2019-01-31 02:20:25
# 4179   Medical Incident  2019-01-30 2019-01-31 02:29:12 2019-01-31 02:33:44
# 1999             Alarms  2019-01-30 2019-01-31 03:12:05 2019-01-31 03:13:29
# 817    Medical Incident  2019-01-30 2019-01-31 03:50:09 2019-01-31 03:51:39
#
#            Dispatch DtTm       Response DtTm       On Scene DtTm  \
# 4217 2019-01-31 00:23:17 2019-01-31 00:24:36 2019-01-31 00:27:56
# 542  2019-01-31 00:46:53 2019-01-31 00:48:52 2019-01-31 00:58:02
# 4664 2019-01-31 00:56:52 2019-01-31 00:58:35 2019-01-31 01:01:26
# 6065 2019-01-31 01:21:27 2019-01-31 01:23:14 2019-01-31 01:24:49
# 2257 2019-01-31 01:09:01 2019-01-31 01:09:13 2019-01-31 01:14:56
# 542                2.0                                           1.0
# 4664               4.0                                           NaN
# 6065               4.0                                           NaN
# 2257               4.0                                           NaN
# 4547               4.0                                           NaN
# 1356               4.0                                           NaN
# 4179               4.0                                           NaN
# 1999               5.0                                           NaN
# 817                4.0                                           NaN
#
#       HSOC Zones  Central Market/Tenderloin Boundary Polygon - Updated  \
# 4217         NaN                                                NaN
# 542          1.0                                                1.0
# 4664         3.0                                                NaN
# 6065         NaN                                                NaN
# 2257         NaN                                                NaN
# 4547         5.0                                                NaN
# 1356         NaN                                                NaN
# 4179         5.0                                                NaN
# 1999         NaN                                                NaN
# 817          3.0                                                NaN
#
#       Neighborhoods  SF Find Neighborhoods  Current Police Districts 2  \
# 4217           26.0                   26.0                         4.0
# 542            32.0                   32.0                         1.0
# 4664           37.0                   37.0                         3.0
# 6065           38.0                   38.0                         3.0
# 2257           38.0                   38.0                         3.0
# 4547           28.0                   28.0                         3.0
# 1356           37.0                   37.0                         3.0
# 4179           38.0                   38.0                         3.0
# 1999          113.0                  113.0                         7.0
# 817            53.0                   53.0                         3.0
#
#       Current Supervisor Districts  TurnoutTime_sec  TurnoutTime_min  \
# 4217                          11.0             79.0         1.316667
# 542                           10.0            119.0         1.983333
# 4664                           5.0            103.0         1.716667
# 6065                           5.0            107.0         1.783333
# 2257                           5.0             12.0         0.200000
# 4547                           5.0            138.0         2.300000
# 1356                           5.0            121.0         2.016667
# 4179                           5.0             96.0         1.600000
# 1999                           5.0             90.0         1.500000
# 817                            2.0            189.0         3.150000
#
#      Evening Incident Prior Available DtTm  TimeSinceLastAvailable_sec  \
# 4217               NO                  NaT                         NaN
# 542                NO  2019-01-31 00:33:01                       832.0
# 4664               NO  2019-01-31 01:07:06                      -614.0
# 6065               NO  2019-01-31 01:16:38                       289.0
# 2257               NO  2019-01-31 01:29:10                     -1209.0
# 4547               NO  2019-01-31 01:40:00                      1328.0
# 1356               NO  2019-01-31 02:14:22                       375.0
# 4179               NO  2019-01-31 02:31:45                       142.0
# 1999               NO  2019-01-31 02:40:57                      1959.0
# 817                NO  2019-01-31 03:40:29                       707.0
#
#       TimeSinceLastAvailable_min
# 4217                         NaN
# 542                    13.866667
# 4664                  -10.233333
# 6065                    4.816667
# 2257                  -20.150000
# 4547                   22.133333
# 1356                    6.250000
# 4179                    2.366667
# 1999                   32.650000
# 817                    11.783333

# %% [markdown]
# # Task 1a: Evening incidents have slower turnout times
# Evening incidents are incidents that are created between the hours of 10:00 PM and 6:00 AM.

# %% [markdown]
# #### Prepare Pandas Data Frame for Analysis

# %%
df_incident_time = df\
    .select('Call Date','Evening Incident','Call Type','Unit Type','TurnoutTime_min','TimeSinceLastAvailable_min')\
    .toPandas()

# %%
df_incident_time['Call Date'] = pd.to_datetime(df_incident_time['Call Date'])
df_incident_time['Call Year'] = df_incident_time['Call Date'].dt.year

# %%
df_incident_time['TurnoutTime_min'] = df_incident_time['TurnoutTime_min'].astype(float)

# %% [markdown]
# ## Quick Visualizations (Identify if Data Quality Issues Exist)

# %%
sns.boxplot(data=df_incident_time, x='Evening Incident', y='TurnoutTime_min');

# %%
# Remove Nulls
df_incident_time = df_incident_time[~df_incident_time.TurnoutTime_min.isnull()]

# %%
# Remove Turnout Times Greater than 1 day
df_incident_time = df_incident_time[df_incident_time.TurnoutTime_min<=(60*24)]

# %%
# Remove Turnout Times Less than 0
df_incident_time = df_incident_time[df_incident_time.TurnoutTime_min>0]

# %%
sns.boxplot(data=df_incident_time, x='Evening Incident', y='TurnoutTime_min');

# %%
plt.figure(figsize=[15,5])
sns.boxplot(data=df_incident_time, x='Call Year', y='TurnoutTime_min', hue='Evening Incident');

# %%
plt.figure(figsize=[5,15])
sns.boxplot(data=df_incident_time, y='Call Type', x='TurnoutTime_min', hue='Evening Incident');

# %% [markdown]
# #### Exclude Turnout Times > 15 minutes (Review Later)

# %%
sns.boxplot(data=df_incident_time[df_incident_time.TurnoutTime_min<=15], x='Evening Incident', y='TurnoutTime_min');

# %%
plt.figure(figsize=[15,5])
sns.boxplot(data=df_incident_time[df_incident_time.TurnoutTime_min<=15], x='Call Year', y='TurnoutTime_min', hue='Evening Incident');

# %%
plt.figure(figsize=[5,15])
sns.boxplot(data=df_incident_time[df_incident_time.TurnoutTime_min<=15], y='Call Type', x='TurnoutTime_min', hue='Evening Incident');

# %%
plt.figure(figsize=[5,15])
sns.boxplot(data=df_incident_time[df_incident_time.TurnoutTime_min<=15], y='Unit Type', x='TurnoutTime_min', hue='Evening Incident');

# %% [markdown]
# # Task 1b: Units with back to back responses have slower turnout times
# A back to back response is defined by a unit being dispatched within 10 minutes of becoming available since the previous incident.

# %% [markdown]
# ## Quick Visualizations (Identify if Data Quality Issues Exist)

# %%
df_incident_time.TimeSinceLastAvailable_min.describe()
# Out:
# count    291720.000000
# mean          6.905822
# std         975.344474
# min        -539.900000
# 25%         -45.200000
# 50%          -7.883333
# 75%           4.800000
# max       44628.350000
# Name: TimeSinceLastAvailable_min, dtype: float64

# %%
df_incident_time['BackToBack'] = np.where(df_incident_time.TimeSinceLastAvailable_min>10, "Outside 10 Minutes", "Within 10 Minutes")

# %%
sns.boxplot(data=df_incident_time[df_incident_time.TurnoutTime_min<=15], x='BackToBack', y='TurnoutTime_min');

# %%
plt.figure(figsize=[5,15])
sns.boxplot(data=df_incident_time[df_incident_time.TurnoutTime_min<=15], y='Call Type', x='TurnoutTime_min', hue='BackToBack');

# %%
plt.figure(figsize=[5,15])
sns.boxplot(data=df_incident_time[df_incident_time.TurnoutTime_min<=15], y='Unit Type', x='TurnoutTime_min', hue='BackToBack');

# %% [markdown]
# # Task 2: Additional trends
#
# Ideas:
# - Location Based Trends
# - Trends over Time
#     - Growth by Incident Type
#     - Response Time
# - Number of Unique Units per Incident (Labor)
#
#
# What I Would Research If I Had More Time:
# - TBD
